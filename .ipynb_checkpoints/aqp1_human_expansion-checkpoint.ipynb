# %% [markdown]
# # Expansion of nodes using Monarch APIs
# * https://api.monarchinitiative.org/api/#/
# * https://scigraph-ontology.monarchinitiative.org/scigraph/docs/#/

# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
# input gene
gene = 'NCBIGene:358'

# output files
path = 'aqp1_human_expansion/aqp1_human'

# %% [markdown]
# ## Graph queries (SciGraph)

# %%
# api address
api = 'https://scigraph-ontology.monarchinitiative.org/scigraph'
endpoint = '/graph'

# %%
# get neighbors (JSON content)
r = requests.get('{}{}/neighbors/{}'.format(api,endpoint,gene))
r.headers
# Out:
# {'Vary': 'Accept, Accept-Encoding', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/json', 'Server': 'nginx/1.10.0 (Ubuntu)', 'Date': 'Wed, 17 May 2017 02:41:50 GMT', 'Content-Encoding': 'gzip', 'Connection': 'keep-alive', 'Cache-Control': 'no-transform, max-age=7200'}

# %%
# Read results 
r.json()
# Out:
# {'edges': [{'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19306058'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9405233'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22334691'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17894331'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22006723'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15948717'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20965731'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16565507'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19913121'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24777974'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17632520'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17409744'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21107133'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24014128'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17273788'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16300893'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23332061'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12477932'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12801959'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23029502'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14592814'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11097616'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14630322'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22269467'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18501347'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26707370'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20795314'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22901921'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11463012'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17854859'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15847654'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26549133'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19619954'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23220481'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25416956'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21244858'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20101282'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21215257'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21237499'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:10559675'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22093331'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23276695'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19268465'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11076974'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18563339'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18538351'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25910212'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19424603'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20063900'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22964306'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26074259'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:10510269'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23313295'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:10839360'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18392839'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26178576'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['equivalentClass']},
#    'obj': 'NCBIGene:358',
#    'pred': 'equivalentClass',
#    'sub': 'ENSEMBL:ENSG00000240583'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22396660'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7544358'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17545093'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12051745'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:10872456'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:1373524'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7507481'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['term replaced by'],
#     'owlType': ['Annotation']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0100001',
#    'sub': 'NCBIGene:1273'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18313673'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19056867'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12002613'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25721378'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25609088'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19060904'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12172703'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17890385'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23393355'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18762715'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:8408657'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19787701'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18349152'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18280225'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26261083'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20149606'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24252214'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18067501'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['equivalentClass']},
#    'obj': 'NCBIGene:358',
#    'pred': 'equivalentClass',
#    'sub': 'OMIM:107776'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25252847'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18202181'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9321919'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12237771'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18080132'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26176849'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20739606'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:27295912'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11408278'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15727941'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:27157540'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7677994'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12522663'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7532004'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11171962'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26823734'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11743202'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16596446'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21063116'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15489334'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:27465156'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23974882'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7504987'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18575775'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9829975'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11909995'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23268390'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15815633'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:8576117'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15024704'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23219802'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16344560'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21538271'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20578142'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25299207'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15135660'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18275976'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20628061'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9806845'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:8584435'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19080511'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15667881'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20431033'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19253825'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16189514'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18282122'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26773069'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26812884'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21612401'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20360993'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17898873'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11773634'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16814974'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:8340403'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12084581'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19726340'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20424473'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20137115'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12690205'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24028651'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16711029'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18665841'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21360438'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18544259'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11922632'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23533145'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19447967'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19522191'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22348807'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16534779'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15563082'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12745312'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24169407'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19670620'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11573934'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22372348'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17645239'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11884383'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21784068'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15502805'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23450058'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16515633'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22310126'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26923194'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21251984'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14753493'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24918928'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7521882'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:22472942'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25582271'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9468475'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19273840'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7521883'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20409716'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11780053'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14675051'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20828513'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:19545896'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12781664'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12853948'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7517253'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21760919'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:21516116'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:24688444'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:16682607'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9177353'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9096382'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18841368'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12399631'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11001937'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7521540'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:9369468'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:12498798'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:14753494'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:10318966'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:15809704'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:7518771'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18247144'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18511455'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:25987071'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23549977'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:3166547'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:17549682'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23376485'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:3049610'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:23317544'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:26717516'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:20461409'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:11532455'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
#     'lbl': ['http://purl.obolibrary.org/obo/IAO_0000136']},
#    'obj': 'NCBIGene:358',
#    'pred': 'IAO:0000136',
#    'sub': 'PMID:18617525'},
#   {'meta': {'isDefinedBy': ['https://data.monarchinitiative.org/ttl/ncbigene.ttl'],
# ...
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19273840',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21760919',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:20137115',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23029502',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18509662',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:1722319',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17632520',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16300893',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15489334',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19726340',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:20360993',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19056867',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16871401',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26773069',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23393355',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11171962',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11408278',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23220481',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11573934',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21215257',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14753494',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18052958',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21896312',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25987071',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:8340403',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15783300',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19619954',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19060904',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18313673',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15809704',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22472942',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16574458',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22310126',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21395179',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21251984',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11914159',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7677994',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23376485',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12522663',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12399631',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23974882',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12745312',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17890385',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22006723',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15667881',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18575775',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19424603',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:27157540',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12498798',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26549133',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:24028651',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:24688444',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22093331',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25910212',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18080132',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22901921',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12801959',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11532455',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12002613',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21063116',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18247144',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:27295912',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12766090',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14675051',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:9405233',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'SO:0001217',
#    'lbl': 'protein_coding_gene',
#    'meta': {'category': ['gene', 'sequence feature'],
#     'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['protein coding gene'],
#     'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': ['sequence'],
#     'http://www.geneontology.org/formats/oboInOwl#id': ['SO:0001217'],
#     'http://www.w3.org/2000/01/rdf-schema#label': ['protein_coding_gene'],
#     'synonym': ['protein coding gene'],
#     'types': ['cliqueLeader', 'gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'PMID:16344560',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14630322',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19268465',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14561230',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:9321919',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26176849',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12137754',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23332061',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:8584435',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22348807',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:2007592',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12237771',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7521540',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7540589',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11884383',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17636236',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:3166547',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:9829975',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25252847',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7517546',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16534779',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7514605',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12027013',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18665841',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23361277',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16711029',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16682607',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17408468',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17409744',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19080511',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18067501',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:20063900',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11909995',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17178220',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7517253',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:7544358',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17219999',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12690205',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15727941',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22396660',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12172703',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22269467',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'ENSEMBL:ENSG00000240583',
#    'lbl': None,
#    'meta': {'category': ['gene', 'sequence feature'],
#     'types': ['gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'PMID:11780053',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21271497',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:15563082',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12781664',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:8576117',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:12853948',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'HGNC:633',
#    'lbl': None,
#    'meta': {'category': ['gene', 'sequence feature'],
#     'types': ['gene', 'Node', 'Class', 'sequence feature']}},
#   {'id': 'PMID:19772916',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22372348',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18275976',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:14753493',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:19522191',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17854859',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17645239',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18202181',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:23219802',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21784068',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26178576',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:21793635',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:9013443',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16565507',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:22334691',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:25609088',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:11743202',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:17511167',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16515633',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'CHR:9606chr7p14.3',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:18349152',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:26115524',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:16814974',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}},
#   {'id': 'PMID:9369468',
#    'lbl': None,
#    'meta': {'types': ['cliqueLeader', 'Node', 'NamedIndividual']}}]}

# %%
neighbors_df = json_normalize(r.json(), 'nodes')
neighbors_df.head()
# Out:
#               id   lbl                                               meta
# 0  PMID:21612401  None  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 1  PMID:16596446  None  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 2  PMID:17012249  None  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 3  PMID:26074259  None  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 4  PMID:17273788  None  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...

# %%
# Analyze neighbours' types
neighbors_df.id.unique()
print('nodes: {}'.format(len(neighbors_df.id.unique())))
# Out:
# nodes: 288

# %%
neighbors_df['node_type'] = neighbors_df.id.apply(lambda x: x.split(':')[0])
neighbors_df.node_type.value_counts()
# Out:
# PMID           279
# NCBIGene         2
# OMIM             1
# ENSEMBL          1
# HGNC             1
# SO               1
# CHR              1
# NCBITaxon        1
# MonarchData      1
# Name: node_type, dtype: int64

# %%
# Filters
# Filter by interaction_type. BUT what are the strings per interaction_type???

# %%
# get reachable nodes (JSON content)
r = requests.get('{}{}/reachablefrom/{}'.format(api,endpoint,gene))
r.headers
# Out:
# {'Server': 'nginx/1.10.0 (Ubuntu)', 'Content-Type': 'application/json', 'Date': 'Wed, 17 May 2017 02:41:54 GMT', 'Vary': 'Accept, Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '447', 'Connection': 'keep-alive', 'Cache-Control': 'no-transform, max-age=7200'}

# %%
# Read results 
r.json()
reach_df = json_normalize(r.json(), 'nodes')
reach_df.head()
# Out:
#                          id                  lbl  \
# 0  MonarchData:ncbigene.ttl                 None
# 1         CHR:9606chr7p14.3                 None
# 2            NCBITaxon:9606         Homo sapiens
# 3                SO:0001217  protein_coding_gene
#
#                                                 meta
# 0    {'types': ['Ontology', 'cliqueLeader', 'Node']}
# 1  {'types': ['cliqueLeader', 'Node', 'NamedIndiv...
# 2  {'synonym': ['man', 'humans', 'human'], 'http:...
# 3  {'synonym': ['protein coding gene'], 'http://w...

# %%
reach_df.id.unique()
print('nodes: {}'.format(len(reach_df.id.unique())))
# Out:
# nodes: 4

# %%
reach_df['node_type'] = reach_df.id.apply(lambda x: x.split(':')[0])
reach_df.node_type.value_counts()
# Out:
# NCBITaxon      1
# MonarchData    1
# SO             1
# CHR            1
# Name: node_type, dtype: int64

# %% [markdown]
# ## Edge Queries (Monarch)

# %%
# api address
api = 'https://api.monarchinitiative.org/api'
endpoint = '/bioentity'

# %%
# get gene info
r = requests.get('{}{}/gene/{}'.format(api,endpoint,gene))
#r = requests.get('https://api.monarchinitiative.org/api/bioentity/gene/%s/phenotypes/'%gene, headers={'Accept':'application/json'})
r.headers
r.json()
# Out:
# {'categories': ['gene', 'sequence feature'],
#  'chromosome': {'categories': None,
#   'consider': None,
#   'deprecated': None,
#   'description': None,
#   'id': None,
#   'label': None,
#   'replaced_by': None,
#   'synonyms': None,
#   'taxon': {'id': None, 'label': None},
#   'types': None,
#   'xrefs': None},
#  'consider': None,
#  'deprecated': None,
#  'description': None,
#  'disease_associations': [{'evidence_graph': {'edges': [{'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'},
#      {'obj': 'DOID:899',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015529VL'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015529VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD015529VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'},
#      {'obj': 'PMID:18988797',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'},
#      {'obj': 'DOID:899',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD015529VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Choledochal Cyst'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'DOID:899', 'lbl': 'choledochal cyst'},
#      {'id': 'PMID:18988797', 'lbl': None},
#      {'id': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '87098b69-b139-40ef-bf2c-485dc301f34a',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:899',
#     'label': 'choledochal cyst',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:18988797',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'DOID:0060164',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'},
#      {'obj': 'PMID:20018876',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD010146VL'},
#      {'obj': 'DOID:0060164',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD010146VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD010146VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'}],
#     'nodes': [{'id': 'PMID:20018876', 'lbl': None},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD010146VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Pain'},
#      {'id': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d', 'lbl': None},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'DOID:0060164', 'lbl': 'pain disorder'}]},
#    'evidence_types': None,
#    'id': '82549ec2-3201-4184-9db0-a5236ffce7d5',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:0060164',
#     'label': 'pain disorder',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:20018876',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'MESH:D015674',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015674VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD015674VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'MESH:D015674',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'PMID:12376462',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015674VL'}],
#     'nodes': [{'id': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99',
#       'lbl': None},
#      {'id': 'MESH:D015674', 'lbl': 'Mammary Neoplasms, Animal'},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD015674VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Mammary Neoplasms, Animal'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'PMID:12376462', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '72359681-f62a-4d0e-b717-963bb0f2e3ea',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D015674',
#     'label': 'Mammary Neoplasms, Animal',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:12376462',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'DOID:14115',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012772VL'},
#      {'obj': 'DOID:14115',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD012772VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012772VL'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'},
#      {'obj': 'PMID:24028651',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD012772VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Shock, Septic'},
#      {'id': 'PMID:24028651', 'lbl': None},
#      {'id': 'DOID:14115', 'lbl': 'toxic shock syndrome'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'c47efd46-1ab0-4ea5-85be-b97889991126',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:14115',
#     'label': 'toxic shock syndrome',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:24028651',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'DOID:10763',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD006973VL'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD006973VL'},
#      {'obj': 'DOID:10763',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD006973VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'},
#      {'obj': 'PMID:22228705',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'}],
#     'nodes': [{'id': 'DOID:10763', 'lbl': 'hypertension'},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD006973VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Hypertension'},
#      {'id': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2', 'lbl': None},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'PMID:22228705', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'af0c53e8-0018-4908-bb8a-364fda43e89f',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:10763',
#     'label': 'hypertension',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:22228705',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD017044VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD017044VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'PMID:18988797',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'OMIM:263200',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'OMIM:263200',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD017044VL'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD017044VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Polycystic Kidney, Autosomal Recessive'},
#      {'id': 'OMIM:263200',
#       'lbl': 'Autosomal recessive polycystic kidney disease'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e', 'lbl': None},
#      {'id': 'PMID:18988797', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'aa764bc1-ca29-4b77-a020-d6a88352802d',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'OMIM:263200',
#     'label': 'Autosomal recessive polycystic kidney disease',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:18988797',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD008325VL'},
#      {'obj': 'MESH:D008325',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD008325VL'},
#      {'obj': 'PMID:12376462',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'},
#      {'obj': 'MESH:D008325',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD008325VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD008325VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Mammary Neoplasms, Experimental'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MESH:D008325', 'lbl': 'Mammary Neoplasms, Experimental'},
#      {'id': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e', 'lbl': None},
#      {'id': 'PMID:12376462', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '24645b90-a77e-480f-b33a-9359928c74ab',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D008325',
#     'label': 'Mammary Neoplasms, Experimental',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:12376462',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD002277VL'},
#      {'obj': 'PMID:12376462',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'},
#      {'obj': 'MESH:D002277',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD002277VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD002277VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'},
#      {'obj': 'MESH:D002277',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'}],
#     'nodes': [{'id': 'MESH:D002277', 'lbl': 'Carcinoma'},
#      {'id': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3', 'lbl': None},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD002277VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Carcinoma'},
#      {'id': 'PMID:12376462', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '8f99a715-6543-468a-83dc-c060b90021aa',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D002277',
#     'label': 'Carcinoma',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:12376462',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD004489VL'},
#      {'obj': 'PMID:22865611',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': 'MESH:D004489',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD004489VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': 'MESH:D004489',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD004489VL'}],
#     'nodes': [{'id': 'MESH:D004489', 'lbl': 'Edema, Cardiac'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'PMID:22865611', 'lbl': None},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD004489VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Edema, Cardiac'},
#      {'id': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '8b6561b0-8092-42b3-8859-7803738560c6',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D004489',
#     'label': 'Edema, Cardiac',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:22865611',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012468VL'},
#      {'obj': 'DOID:8850',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012468VL'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD012468VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'},
#      {'obj': 'PMID:16762588',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'},
#      {'obj': 'DOID:8850',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'}],
#     'nodes': [{'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60', 'lbl': None},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD012468VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Salivary Gland Neoplasms'},
#      {'id': 'DOID:8850', 'lbl': 'salivary gland cancer'},
#      {'id': 'PMID:16762588', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'c042c18b-535a-41ee-8d08-ad3389d1daf3',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:8850',
#     'label': 'salivary gland cancer',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:16762588',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'families': None,
#  'full_name': None,
#  'function_associations': None,
#  'genotype_associations': [],
#  'homology_associations': [{'evidence_graph': {'edges': [{'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00'},
#      {'obj': 'NCBIGene:843653',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00'},
#      {'obj': 'NCBIGene:843653',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'}],
#     'nodes': [{'id': 'NCBIGene:843653', 'lbl': 'TIP3;1'},
#      {'id': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '6bac9929-5535-4d13-afe0-db9bce756754',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:843653',
#     'label': 'TIP3;1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:3702', 'label': 'Arabidopsis thaliana'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#      {'obj': 'NCBIGene:123722',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#      {'obj': 'NCBIGene:123722', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'NCBIGene:123722', 'lbl': 'FSD2'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'}]},
#    'evidence_types': None,
#    'id': '565ed0cf-5e0b-4d72-8b20-c6b73740c588',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:123722',
#     'label': 'FSD2',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#      {'obj': 'NCBIGene:22806', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:22806',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'NCBIGene:22806', 'lbl': 'IKZF3'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '55af1514-49d5-4804-80a0-ddbd5e4b0673',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:22806',
#     'label': 'IKZF3',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'NCBIGene:6925',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'NCBIGene:6925', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:6925', 'lbl': 'TCF4'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '83183ff9-36a7-4f9b-86bc-f0f581403858',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:6925',
#     'label': 'TCF4',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:2353',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#      {'obj': 'NCBIGene:2353', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'}],
#     'nodes': [{'id': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37',
#       'lbl': None},
#      {'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'NCBIGene:2353', 'lbl': 'FOS'}]},
#    'evidence_types': None,
#    'id': '5974fd98-a947-495f-a967-3529288824a0',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:2353',
#     'label': 'FOS',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:824647',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6'},
#      {'obj': 'NCBIGene:824647',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'}],
#     'nodes': [{'id': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6',
#       'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:824647', 'lbl': 'PIP2;5'}]},
#    'evidence_types': None,
#    'id': '56b77701-1ba0-4a35-a73d-5d0a2564ae49',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:824647',
#     'label': 'PIP2;5',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:3702', 'label': 'Arabidopsis thaliana'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:816186',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:816186',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62'}],
#     'nodes': [{'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:816186', 'lbl': 'PIP2;8'},
#      {'id': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '7757e857-7eea-4814-8b31-36fa7e1883e0',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:816186',
#     'label': 'PIP2;8',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:3702', 'label': 'Arabidopsis thaliana'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#      {'obj': 'NCBIGene:125115', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:125115',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'NCBIGene:125115', 'lbl': 'KRT40'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'd93622d5-b3ce-4014-9566-165d8edbdd0b',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:125115',
#     'label': 'KRT40',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'FlyBase:FBgn0015872',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a'},
#      {'obj': 'FlyBase:FBgn0015872',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a'}],
#     'nodes': [{'id': 'FlyBase:FBgn0015872', 'lbl': 'Drip'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a', 'lbl': None},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '5b335768-c3d1-418a-a7fb-c1c48339e9f6',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'FlyBase:FBgn0015872',
#     'label': 'Drip',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:7227', 'label': 'Drosophila melanogaster'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:420384',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd'},
#      {'obj': 'NCBIGene:420384',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:358'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd'}],
#     'nodes': [{'id': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd',
#       'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:420384', 'lbl': 'AQP1'}]},
#    'evidence_types': None,
#    'id': 'b880991b-2292-4ac8-8bea-79ae9b9f56dc',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:420384',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9031', 'label': 'Gallus gallus'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000020',
#     'label': 'in 1 to 1 orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'id': 'NCBIGene:358',
#  'interaction_associations': None,
#  'label': 'AQP1',
#  'literature_associations': None,
#  'pathway_associations': None,
#  'phenotype_associations': [],
#  'replaced_by': None,
#  'sequence_features': None,
#  'summaries': None,
#  'synonyms': [{'pred': 'synonym',
#    'val': 'channel-like integral membrane protein, 28-kDa',
#    'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'water channel protein for red blood cells and kidney proximal tubule',
#    'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'aquaporin 1 (Colton blood group)',
#    'xrefs': None},
#   {'pred': 'synonym', 'val': 'aquaporin-1', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'AQP1_HUMAN', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'urine water channel', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'CO', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'AQP1', 'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'aquaporin 1 (channel-forming integral protein, 28kDa, CO blood group)',
#    'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'aquaporin 1, Colton blood group antigen',
#    'xrefs': None},
#   {'pred': 'synonym', 'val': 'aquaporin-CHIP', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'AQP-CHIP', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'CHIP28', 'xrefs': None}],
#  'systematic_name': None,
#  'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#  'transcripts': None,
#  'types': None,
#  'xrefs': None}

# %%
# get gene-gene interactions
r = requests.get('{}{}/gene/{}/interactions/'.format(api,endpoint,gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 42

# %%
ggi_df = json_normalize(r.json(), 'objects')
ggi_df.columns = ['gene_id']
ggi_df.head(2)
# Out:
#               gene_id
# 0  NCBIGene:100996717
# 1      NCBIGene:10188

# %%
ggi_df.to_csv('{}_ggi.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get gene-phenotype
r = requests.get('{}{}/gene/{}/phenotypes/'.format(api,endpoint,gene))
nassociations = len(r.json()['associations'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 0

# %%
# Get gene-disease
r = requests.get('{}{}/gene/{}/diseases/'.format(api,endpoint,gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 13

# %%
r_dict = r.json()
gda_df = json_normalize(r_dict, 'objects')
gda_df.columns = ['disease_id']
gda_df.head(2)
# Out:
#      disease_id
# 0  DOID:0060164
# 1    DOID:10763

# %%
gda_df.to_csv('{}_gene_disease.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get gene-function
r = requests.get('{}{}/gene/{}/function/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
r.json()
# Out:
# Number of nodes associated are 0
# {'associations': [],
#  'compact_associations': None,
#  'facet_counts': {'isa_partof_closure': {}, 'taxon_label': {}},
#  'facet_pivot': None,
#  'numFound': None,
#  'objects': [],
#  'start': None}

# %%
# get gene-expressedInAnatomy
r = requests.get('{}{}/gene/{}/expressed/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 20

# %%
r_data = r.json()
gaa_df = json_normalize(r_data, 'objects')
gaa_df.columns = ['expressed_in_anatomy']
gaa_df.head(2)
# Out:
#   expressed_in_anatomy
# 0       UBERON:0000007
# 1       UBERON:0000057

# %%
gaa_df.to_csv('{}_gene_anatomy.tsv'.format(path), sep='\t', index=False, header=True)

# %%
# get gene-pub
r = requests.get('{}{}/gene/{}/pubs/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 0

# %%
# get gene-homolog
r = requests.get('{}{}/gene/{}/homologs/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 49

# %%
r_dict = r.json()
gha_df = json_normalize(r_dict, 'objects')
gha_df.columns = ['homolog_id']
gha_df.head(2)
# Out:
#             homolog_id
# 0  FlyBase:FBgn0015872
# 1  FlyBase:FBgn0033635

# %%
gha_df.to_csv('{}_gene_homolog.tsv'.format(path), sep='\t', index=False, header=True)
