# %% [markdown]
# # Expansion of nodes using Monarch APIs
# * https://api.monarchinitiative.org/api/#/
# * https://scigraph-ontology.monarchinitiative.org/scigraph/docs/#/

# %%
import pandas as pd

# %% [markdown]
# ## Graph queries (SciGraph)
# ### Get Neighbors
# #### GET /graph/neighbors/{id}

# %%
# Donwload neighbors 
# id: NCBIGene:358
# Default parameters
# curl -X GET --header 'Accept: text/tab-separated-values' 'https://scigraph-ontology.monarchinitiative.org/scigraph/graph/neighbors/NCBIGene%3A358?depth=1&blankNodes=false&direction=BOTH&entail=false&project=*' > aqp1_getNeighbors_defaultparm.tsv

# %%
# Read results (depth=1)
layer1_df = pd.read_table('/home/nuria/workspace/monarch/aqp1_getNeighbors_defaultparm.tsv')
layer1_df.head()
# Out:
#               id label categories
# 0  PMID:21612401   NaN         []
# 1  PMID:16596446   NaN         []
# 2  PMID:17012249   NaN         []
# 3  PMID:26074259   NaN         []
# 4  PMID:17273788   NaN         []

# %%
# Analyze neighbours' types
layer1_df.describe()
# Out:
#                    id label categories
# count             288     4        288
# unique            288     4          2
# top     NCBIGene:1273  AQP1         []
# freq                1     1        283

# %%
layer1_df.id.unique()
# Out:
# array(['PMID:21612401', 'PMID:16596446', 'PMID:17012249', 'PMID:26074259',
#        'PMID:17273788', 'PMID:23928039', 'PMID:7491270', 'PMID:18544259',
#        'PMID:18538351', 'PMID:1373524', 'PMID:19670620', 'PMID:23268390',
#        'PMID:24777974', 'PMID:7521883', 'PMID:12051745', 'PMID:12084581',
#        'PMID:21360438', 'PMID:20578142', 'PMID:22964306', 'PMID:7532004',
#        'PMID:8408657', 'PMID:1510932', 'PMID:24014128', 'PMID:26838488',
#        'PMID:20461409', 'PMID:18282122', 'PMID:21244858', 'PMID:23450058',
#        'PMID:7507481', 'PMID:19787701', 'PMID:10872456', 'PMID:11773634',
#        'PMID:17545093', 'PMID:12477932', 'PMID:26823734', 'PMID:18563339',
#        'PMID:26151179', 'PMID:15135660', 'PMID:11922632', 'PMID:18501347',
#        'PMID:17077939', 'PMID:15948717', 'PMID:11076974', 'PMID:20969805',
#        'PMID:10564231', 'PMID:20806077', 'PMID:18280225', 'PMID:20149606',
#        'PMID:21373963', 'PMID:14701836', 'PMID:26181025', 'PMID:26786101',
#        'PMID:16189514', 'PMID:23313295', 'PMID:17549682', 'PMID:24803718',
#        'PMID:26707370', 'OMIM:107776', 'PMID:21538271', 'PMID:7518771',
#        'NCBITaxon:9606', 'PMID:7504987', 'PMID:18392839', 'PMID:20739606',
#        'PMID:16481371', 'PMID:9096382', 'PMID:17894331', 'PMID:24252214',
#        'PMID:23276695', 'PMID:16698771', 'PMID:20431033', 'PMID:21516116',
#        'PMID:20101282', 'PMID:15024704', 'PMID:10839360', 'PMID:15502805',
#        'PMID:20795314', 'PMID:26261083', 'PMID:20424473', 'PMID:24918928',
#        'PMID:9468475', 'PMID:19545896', 'PMID:25721378', 'PMID:18617525',
#        'PMID:21107133', 'PMID:14521551', 'PMID:20628086', 'PMID:21252246',
#        'PMID:19447967', 'PMID:20628061', 'PMID:23533145', 'PMID:9177353',
#        'PMID:14514735', 'PMID:24086369', 'PMID:27465156', 'PMID:25495276',
#        'PMID:26812884', 'PMID:24169407', 'PMID:7530250', 'PMID:18470935',
#        'PMID:22901156', 'PMID:25582271', 'MonarchData:ncbigene.ttl',
#        'PMID:24333057', 'PMID:10559675', 'PMID:19253825', 'PMID:15847654',
#        'PMID:26717516', 'PMID:23317544', 'PMID:21237499', 'PMID:11034202',
#        'PMID:18510579', 'PMID:10873606', 'PMID:3049610', 'PMID:26923194',
#        'PMID:10510269', 'PMID:8703970', 'PMID:18511455', 'PMID:19306058',
#        'PMID:21551254', 'PMID:7693713', 'PMID:20965731', 'PMID:11463012',
#        'PMID:25416956', 'PMID:19584911', 'PMID:25299207', 'NCBIGene:358',
#        'PMID:17898873', 'PMID:15815633', 'PMID:15326289', 'PMID:21839760',
#        'PMID:11097616', 'PMID:9806845', 'PMID:24493792', 'PMID:14592814',
#        'PMID:18762715', 'PMID:7521882', 'PMID:20409716', 'PMID:23949237',
#        'PMID:23549977', 'NCBIGene:1273', 'PMID:18841368', 'PMID:11001937',
#        'PMID:19913121', 'PMID:10318966', 'PMID:16133142', 'PMID:19472194',
#        'PMID:20828513', 'PMID:19273840', 'PMID:21760919', 'PMID:20137115',
#        'PMID:23029502', 'PMID:18509662', 'PMID:1722319', 'PMID:17632520',
#        'PMID:16300893', 'PMID:15489334', 'PMID:19726340', 'PMID:20360993',
#        'PMID:19056867', 'PMID:16871401', 'PMID:26773069', 'PMID:23393355',
#        'PMID:11171962', 'PMID:11408278', 'PMID:23220481', 'PMID:11573934',
#        'PMID:21215257', 'PMID:14753494', 'PMID:18052958', 'PMID:21896312',
#        'PMID:25987071', 'PMID:8340403', 'PMID:15783300', 'PMID:19619954',
#        'PMID:19060904', 'PMID:18313673', 'PMID:15809704', 'PMID:22472942',
#        'PMID:16574458', 'PMID:22310126', 'PMID:21395179', 'PMID:21251984',
#        'PMID:11914159', 'PMID:7677994', 'PMID:23376485', 'PMID:12522663',
#        'PMID:12399631', 'PMID:23974882', 'PMID:12745312', 'PMID:17890385',
#        'PMID:22006723', 'PMID:15667881', 'PMID:18575775', 'PMID:19424603',
#        'PMID:27157540', 'PMID:12498798', 'PMID:26549133', 'PMID:24028651',
#        'PMID:24688444', 'PMID:22093331', 'PMID:25910212', 'PMID:18080132',
#        'PMID:22901921', 'PMID:12801959', 'PMID:11532455', 'PMID:12002613',
#        'PMID:21063116', 'PMID:18247144', 'PMID:27295912', 'PMID:12766090',
#        'PMID:14675051', 'PMID:9405233', 'SO:0001217', 'PMID:16344560',
#        'PMID:14630322', 'PMID:19268465', 'PMID:14561230', 'PMID:9321919',
#        'PMID:26176849', 'PMID:12137754', 'PMID:23332061', 'PMID:8584435',
#        'PMID:22348807', 'PMID:2007592', 'PMID:12237771', 'PMID:7521540',
#        'PMID:7540589', 'PMID:11884383', 'PMID:17636236', 'PMID:3166547',
#        'PMID:9829975', 'PMID:25252847', 'PMID:7517546', 'PMID:16534779',
#        'PMID:7514605', 'PMID:12027013', 'PMID:18665841', 'PMID:23361277',
#        'PMID:16711029', 'PMID:16682607', 'PMID:17408468', 'PMID:17409744',
#        'PMID:19080511', 'PMID:18067501', 'PMID:20063900', 'PMID:11909995',
#        'PMID:17178220', 'PMID:7517253', 'PMID:7544358', 'PMID:17219999',
#        'PMID:12690205', 'PMID:15727941', 'PMID:22396660', 'PMID:12172703',
#        'PMID:22269467', 'ENSEMBL:ENSG00000240583', 'PMID:11780053',
#        'PMID:21271497', 'PMID:15563082', 'PMID:12781664', 'PMID:8576117',
#        'PMID:12853948', 'HGNC:633', 'PMID:19772916', 'PMID:22372348',
#        'PMID:18275976', 'PMID:14753493', 'PMID:19522191', 'PMID:17854859',
#        'PMID:17645239', 'PMID:18202181', 'PMID:23219802', 'PMID:21784068',
#        'PMID:26178576', 'PMID:21793635', 'PMID:9013443', 'PMID:16565507',
#        'PMID:22334691', 'PMID:25609088', 'PMID:11743202', 'PMID:17511167',
#        'PMID:16515633', 'CHR:9606chr7p14.3', 'PMID:18349152',
#        'PMID:26115524', 'PMID:16814974', 'PMID:9369468'], dtype=object)

# %%
layer1_df['node_type'] = layer1_df.id.apply(lambda x: x.split(':')[0])
layer1_df.node_type.value_counts()
# Out:
# PMID           279
# NCBIGene         2
# OMIM             1
# HGNC             1
# NCBITaxon        1
# CHR              1
# ENSEMBL          1
# MonarchData      1
# SO               1
# Name: node_type, dtype: int64

# %%
# Filters
# Depth = 2 does not work
# Filter by interaction_type. BUT what are the strings per interaction_type???

# %% [markdown]
# ### Get reachable nodes
# #### GET /graph/reachablefrom/{id}

# %%
# Download reachable nodes
# id: NCBIGene:358
# Default parameters
# curl -X GET --header 'Accept: text/tab-separated-values' 'https://scigraph-ontology.monarchinitiative.org/scigraph/graph/reachablefrom/NCBIGene%3A358' > aqp1_getReachableNodes_defaultparm.tsv

# %%
# Read results 
reach_df = pd.read_table('/home/nuria/workspace/monarch/aqp1_getReachableNodes_defaultparm.tsv')
reach_df.head()
# Out:
#                          id                label                categories
# 0  MonarchData:ncbigene.ttl                  NaN                        []
# 1         CHR:9606chr7p14.3                  NaN                        []
# 2            NCBITaxon:9606         Homo sapiens                        []
# 3                SO:0001217  protein_coding_gene  [gene, sequence feature]

# %%
# Analyze neighbours' types
reach_df.describe()
# Out:
#                        id         label categories
# count                   4             2          4
# unique                  4             2          2
# top     CHR:9606chr7p14.3  Homo sapiens         []
# freq                    1             1          3

# %%
reach_df.id.unique()
# Out:
# array(['MonarchData:ncbigene.ttl', 'CHR:9606chr7p14.3', 'NCBITaxon:9606',
#        'SO:0001217'], dtype=object)

# %%
reach_df['node_type'] = reach_df.id.apply(lambda x: x.split(':')[0])
reach_df.node_type.value_counts()
# Out:
# MonarchData    1
# SO             1
# NCBITaxon      1
# CHR            1
# Name: node_type, dtype: int64

# %% [markdown]
# ## Edge Queries (Monarch)
# ### Get GGI
# #### GET /bioentity/gene/{id}/interactions/

# %%
# Download gene-gene interactions
# id: NCBIGene:358
# Default parameters
# curl -X GET --header 'Accept: application/json' 'https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene%3A358/interactions/?fetch_objects=true&rows=20' > aqp1_getGeneInteractions_defaultparm.json

# %%
# Read results
import json
from pprint import pprint
from pandas.io.json import json_normalize

with open('/home/nuria/workspace/monarch/aqp1_getGeneInteractions_defaultparm.json') as ggi_f:
    data = json.load(ggi_f)
ggi_f.close()
pprint(data)
# Out:
# {'associations': [{'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#                                                 {'obj': 'NCBIGene:123722',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#                                                 {'obj': 'NCBIGene:123722',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'NCBIGene:123722',
#                                                  'lbl': 'FSD2'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'}]},
#                    'evidence_types': None,
#                    'id': '565ed0cf-5e0b-4d72-8b20-c6b73740c588',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:123722',
#                               'label': 'FSD2',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#                                                 {'obj': 'NCBIGene:22806',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:22806',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'NCBIGene:22806',
#                                                  'lbl': 'IKZF3'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34',
#                                                  'lbl': None}]},
#                    'evidence_types': None,
#                    'id': '55af1514-49d5-4804-80a0-ddbd5e4b0673',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:22806',
#                               'label': 'IKZF3',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#                                                 {'obj': 'NCBIGene:6925',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#                                                 {'obj': 'NCBIGene:6925',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:6925',
#                                                  'lbl': 'TCF4'},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc',
#                                                  'lbl': None}]},
#                    'evidence_types': None,
#                    'id': '83183ff9-36a7-4f9b-86bc-f0f581403858',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:6925',
#                               'label': 'TCF4',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:2353',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#                                                 {'obj': 'NCBIGene:2353',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'}],
#                                       'nodes': [{'id': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37',
#                                                  'lbl': None},
#                                                 {'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'NCBIGene:2353',
#                                                  'lbl': 'FOS'}]},
#                    'evidence_types': None,
#                    'id': '5974fd98-a947-495f-a967-3529288824a0',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:2353',
#                               'label': 'FOS',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#                                                 {'obj': 'NCBIGene:125115',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:125115',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'NCBIGene:125115',
#                                                  'lbl': 'KRT40'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858',
#                                                  'lbl': None}]},
#                    'evidence_types': None,
#                    'id': 'd93622d5-b3ce-4014-9566-165d8edbdd0b',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:125115',
#                               'label': 'KRT40',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:3881',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:0fd1c4d06bf38a9d5d4bf053eb111f1eeafa50d6'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:0fd1c4d06bf38a9d5d4bf053eb111f1eeafa50d6'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:0fd1c4d06bf38a9d5d4bf053eb111f1eeafa50d6'},
#                                                 {'obj': 'NCBIGene:3881',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:0fd1c4d06bf38a9d5d4bf053eb111f1eeafa50d6'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'MONARCH:0fd1c4d06bf38a9d5d4bf053eb111f1eeafa50d6',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:3881',
#                                                  'lbl': 'KRT31'}]},
#                    'evidence_types': None,
#                    'id': '941e4979-5bde-4404-a3c6-deff9982b8a5',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:3881',
#                               'label': 'KRT31',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:54507',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:e996b89c4450e2184e81d7573f995b83ddcd768b'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:e996b89c4450e2184e81d7573f995b83ddcd768b'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:e996b89c4450e2184e81d7573f995b83ddcd768b'},
#                                                 {'obj': 'PMID:19060904',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:e996b89c4450e2184e81d7573f995b83ddcd768b'},
#                                                 {'obj': 'NCBIGene:54507',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'}],
#                                       'nodes': [{'id': 'NCBIGene:54507',
#                                                  'lbl': 'ADAMTSL4'},
#                                                 {'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'MONARCH:e996b89c4450e2184e81d7573f995b83ddcd768b',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'PMID:19060904',
#                                                  'lbl': None}]},
#                    'evidence_types': None,
#                    'id': '6d700a65-ba35-43c7-8b80-470bb5cefec8',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:54507',
#                               'label': 'ADAMTSL4',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:19060904',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:52586d30128bd8737fd2a152e8f0fb2ae1b20621'},
#                                                 {'obj': 'NCBIGene:79734',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:52586d30128bd8737fd2a152e8f0fb2ae1b20621'},
#                                                 {'obj': 'PMID:16189514',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:52586d30128bd8737fd2a152e8f0fb2ae1b20621'},
#                                                 {'obj': 'NCBIGene:79734',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:52586d30128bd8737fd2a152e8f0fb2ae1b20621'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'NCBIGene:79734',
#                                                  'lbl': 'KCTD17'},
#                                                 {'id': 'MONARCH:52586d30128bd8737fd2a152e8f0fb2ae1b20621',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'PMID:16189514',
#                                                  'lbl': None}]},
#                    'evidence_types': None,
#                    'id': 'f321a99f-2153-4c9d-a122-4d8230d88e14',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:79734',
#                               'label': 'KCTD17',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:16189514',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:386675',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:386675',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:ba1646ee0bd2f584d5d4a0ffa4a5e015e95f656a'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:ba1646ee0bd2f584d5d4a0ffa4a5e015e95f656a'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:ba1646ee0bd2f584d5d4a0ffa4a5e015e95f656a'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:ba1646ee0bd2f584d5d4a0ffa4a5e015e95f656a'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'MONARCH:ba1646ee0bd2f584d5d4a0ffa4a5e015e95f656a',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'NCBIGene:386675',
#                                                  'lbl': 'KRTAP10-7'}]},
#                    'evidence_types': None,
#                    'id': '94fd738a-845e-4b72-bd0a-eeb74a7f2840',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:386675',
#                               'label': 'KRTAP10-7',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:22807',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:6a17604a1d2b5ebba6cc6565829f69a78f2e1b87'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:6a17604a1d2b5ebba6cc6565829f69a78f2e1b87'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:6a17604a1d2b5ebba6cc6565829f69a78f2e1b87'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:6a17604a1d2b5ebba6cc6565829f69a78f2e1b87'},
#                                                 {'obj': 'NCBIGene:22807',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'MONARCH:6a17604a1d2b5ebba6cc6565829f69a78f2e1b87',
#                                                  'lbl': None},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:22807',
#                                                  'lbl': 'IKZF2'},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'}]},
#                    'evidence_types': None,
#                    'id': 'c9e1ef9d-ff4a-42e9-bdec-a234b25e4a1d',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:22807',
#                               'label': 'IKZF2',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:85376',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:2abf68a7739b13559056f419f583f958b66d8192'},
#                                                 {'obj': 'NCBIGene:85376',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:2abf68a7739b13559056f419f583f958b66d8192'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:2abf68a7739b13559056f419f583f958b66d8192'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
# ...
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:f8641e2939606755dce08e780405938208194fd3'}],
#                                       'nodes': [{'id': 'MONARCH:f8641e2939606755dce08e780405938208194fd3',
#                                                  'lbl': None},
#                                                 {'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:7186',
#                                                  'lbl': 'TRAF2'},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'}]},
#                    'evidence_types': None,
#                    'id': 'd5e60adb-b221-4a5f-87ae-cddae495143a',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:7186',
#                               'label': 'TRAF2',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:73eebbb34779c4eeb6c0a6ca974f63e16139c918'},
#                                                 {'obj': 'NCBIGene:23281',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:73eebbb34779c4eeb6c0a6ca974f63e16139c918'},
#                                                 {'obj': 'NCBIGene:23281',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:73eebbb34779c4eeb6c0a6ca974f63e16139c918'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:73eebbb34779c4eeb6c0a6ca974f63e16139c918'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'MONARCH:73eebbb34779c4eeb6c0a6ca974f63e16139c918',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:23281',
#                                                  'lbl': 'MTUS2'}]},
#                    'evidence_types': None,
#                    'id': '744ed6e1-678b-4d51-a532-737325692562',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:23281',
#                               'label': 'MTUS2',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None},
#                   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:54793',
#                                                  'pred': 'OBAN:association_has_object',
#                                                  'sub': 'MONARCH:ffcd6834413ef5d33cb63ee08d324a7468777abb'},
#                                                 {'obj': 'NCBIGene:54793',
#                                                  'pred': 'RO:0002434',
#                                                  'sub': 'NCBIGene:358'},
#                                                 {'obj': 'NCBIGene:358',
#                                                  'pred': 'OBAN:association_has_subject',
#                                                  'sub': 'MONARCH:ffcd6834413ef5d33cb63ee08d324a7468777abb'},
#                                                 {'obj': 'ECO:0000068',
#                                                  'pred': 'RO:0002558',
#                                                  'sub': 'MONARCH:ffcd6834413ef5d33cb63ee08d324a7468777abb'},
#                                                 {'obj': 'PMID:25416956',
#                                                  'pred': 'dc:source',
#                                                  'sub': 'MONARCH:ffcd6834413ef5d33cb63ee08d324a7468777abb'}],
#                                       'nodes': [{'id': 'ECO:0000068',
#                                                  'lbl': 'yeast 2-hybrid '
#                                                         'evidence'},
#                                                 {'id': 'PMID:25416956',
#                                                  'lbl': None},
#                                                 {'id': 'MONARCH:ffcd6834413ef5d33cb63ee08d324a7468777abb',
#                                                  'lbl': None},
#                                                 {'id': 'NCBIGene:358',
#                                                  'lbl': 'AQP1'},
#                                                 {'id': 'NCBIGene:54793',
#                                                  'lbl': 'KCTD9'}]},
#                    'evidence_types': None,
#                    'id': 'd0f43299-ea9b-46be-8f29-9536645f4e9e',
#                    'object': {'categories': None,
#                               'consider': None,
#                               'deprecated': None,
#                               'description': None,
#                               'id': 'NCBIGene:54793',
#                               'label': 'KCTD9',
#                               'replaced_by': None,
#                               'synonyms': None,
#                               'taxon': {'id': 'NCBITaxon:9606',
#                                         'label': 'Homo sapiens'},
#                               'types': None,
#                               'xrefs': None},
#                    'object_extension': None,
#                    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#                    'publications': [{'categories': None,
#                                      'consider': None,
#                                      'deprecated': None,
#                                      'description': None,
#                                      'id': 'PMID:25416956',
#                                      'label': None,
#                                      'replaced_by': None,
#                                      'synonyms': None,
#                                      'types': None}],
#                    'qualifiers': None,
#                    'relation': {'categories': None,
#                                 'consider': None,
#                                 'deprecated': None,
#                                 'description': None,
#                                 'id': 'RO:0002434',
#                                 'label': 'interacts with',
#                                 'replaced_by': None,
#                                 'synonyms': None,
#                                 'types': None},
#                    'slim': None,
#                    'subject': {'categories': None,
#                                'consider': None,
#                                'deprecated': None,
#                                'description': None,
#                                'id': 'NCBIGene:358',
#                                'label': 'AQP1',
#                                'replaced_by': None,
#                                'synonyms': None,
#                                'taxon': {'id': 'NCBITaxon:9606',
#                                          'label': 'Homo sapiens'},
#                                'types': None,
#                                'xrefs': None},
#                    'subject_extension': None,
#                    'type': None}],
#  'compact_associations': None,
#  'facet_counts': {'object_closure': {'BFO:0000001': 42,
#                                      'BFO:0000002': 42,
#                                      'BFO:0000031': 42,
#                                      'ENSEMBL:ENSG00000030419': 1,
#                                      'ENSEMBL:ENSG00000056558': 1,
#                                      'ENSEMBL:ENSG00000061938': 1,
#                                      'ENSEMBL:ENSG00000080561': 1,
#                                      'ENSEMBL:ENSG00000087077': 1,
#                                      'ENSEMBL:ENSG00000091844': 1,
#                                      'ENSEMBL:ENSG00000094796': 1,
#                                      'ENSEMBL:ENSG00000095713': 1,
#                                      'ENSEMBL:ENSG00000100379': 1,
#                                      'ENSEMBL:ENSG00000104756': 1,
#                                      'ENSEMBL:ENSG00000107175': 1,
#                                      'ENSEMBL:ENSG00000112559': 1,
#                                      'ENSEMBL:ENSG00000113595': 1,
#                                      'ENSEMBL:ENSG00000127191': 1,
#                                      'GENO:0000014': 42,
#                                      'GENO:0000701': 42,
#                                      'SO:0000001': 42,
#                                      'SO:0000110': 42,
#                                      'SO:0000704': 42,
#                                      'SO:0001217': 41,
#                                      'SO:0001411': 42,
#                                      'owl:Thing': 42},
#                   'subject_taxon_label': {'Homo sapiens': 42}},
#  'facet_pivot': None,
#  'numFound': None,
#  'objects': ['NCBIGene:100996717',
#              'NCBIGene:10188',
#              'NCBIGene:102466755',
#              'NCBIGene:10253',
#              'NCBIGene:10488',
#              'NCBIGene:11007',
#              'NCBIGene:11043',
#              'NCBIGene:123722',
#              'NCBIGene:125115',
#              'NCBIGene:158405',
#              'NCBIGene:22806',
#              'NCBIGene:22807',
#              'NCBIGene:23281',
#              'NCBIGene:2353',
#              'NCBIGene:26575',
#              'NCBIGene:284001',
#              'NCBIGene:285622',
#              'NCBIGene:30008',
#              'NCBIGene:339834',
#              'NCBIGene:358',
#              'NCBIGene:373',
#              'NCBIGene:386675',
#              'NCBIGene:386682',
#              'NCBIGene:3881',
#              'NCBIGene:3884',
#              'NCBIGene:4188',
#              'NCBIGene:54507',
#              'NCBIGene:54793',
#              'NCBIGene:55118',
#              'NCBIGene:64651',
#              'NCBIGene:64753',
#              'NCBIGene:6477',
#              'NCBIGene:6925',
#              'NCBIGene:7185',
#              'NCBIGene:7186',
#              'NCBIGene:79734',
#              'NCBIGene:80817',
#              'NCBIGene:83755',
#              'NCBIGene:83899',
#              'NCBIGene:85291',
#              'NCBIGene:85376',
#              'NCBIGene:8601'],
#  'start': None}

# %%
ggi_df = json_normalize(data, 'objects')
ggi_df.columns = ['entrez']
ggi_df
# Out:
#                 entrez
# 0   NCBIGene:100996717
# 1       NCBIGene:10188
# 2   NCBIGene:102466755
# 3       NCBIGene:10253
# 4       NCBIGene:10488
# 5       NCBIGene:11007
# 6       NCBIGene:11043
# 7      NCBIGene:123722
# 8      NCBIGene:125115
# 9      NCBIGene:158405
# 10      NCBIGene:22806
# 11      NCBIGene:22807
# 12      NCBIGene:23281
# 13       NCBIGene:2353
# 14      NCBIGene:26575
# 15     NCBIGene:284001
# 16     NCBIGene:285622
# 17      NCBIGene:30008
# 18     NCBIGene:339834
# 19        NCBIGene:358
# 20        NCBIGene:373
# 21     NCBIGene:386675
# 22     NCBIGene:386682
# 23       NCBIGene:3881
# 24       NCBIGene:3884
# 25       NCBIGene:4188
# 26      NCBIGene:54507
# 27      NCBIGene:54793
# 28      NCBIGene:55118
# 29      NCBIGene:64651
# 30      NCBIGene:64753
# 31       NCBIGene:6477
# 32       NCBIGene:6925
# 33       NCBIGene:7185
# 34       NCBIGene:7186
# 35      NCBIGene:79734
# 36      NCBIGene:80817
# 37      NCBIGene:83755
# 38      NCBIGene:83899
# 39      NCBIGene:85291
# 40      NCBIGene:85376
# 41       NCBIGene:8601

# %%
import ijson

with open('/home/nuria/workspace/monarch/aqp1_getGeneInteractions_defaultparm.json','r') as ggi_f:
    objects = ijson.items(ggi_f, 'objects.item')
    columns = list(objects)
ggi_f.close()
print(columns[0])
# Out:
# NCBIGene:100996717

# %%
# Analyze neighbours' types
columns
# Out:
# ['NCBIGene:100996717',
#  'NCBIGene:10188',
#  'NCBIGene:102466755',
#  'NCBIGene:10253',
#  'NCBIGene:10488',
#  'NCBIGene:11007',
#  'NCBIGene:11043',
#  'NCBIGene:123722',
#  'NCBIGene:125115',
#  'NCBIGene:158405',
#  'NCBIGene:22806',
#  'NCBIGene:22807',
#  'NCBIGene:23281',
#  'NCBIGene:2353',
#  'NCBIGene:26575',
#  'NCBIGene:284001',
#  'NCBIGene:285622',
#  'NCBIGene:30008',
#  'NCBIGene:339834',
#  'NCBIGene:358',
#  'NCBIGene:373',
#  'NCBIGene:386675',
#  'NCBIGene:386682',
#  'NCBIGene:3881',
#  'NCBIGene:3884',
#  'NCBIGene:4188',
#  'NCBIGene:54507',
#  'NCBIGene:54793',
#  'NCBIGene:55118',
#  'NCBIGene:64651',
#  'NCBIGene:64753',
#  'NCBIGene:6477',
#  'NCBIGene:6925',
#  'NCBIGene:7185',
#  'NCBIGene:7186',
#  'NCBIGene:79734',
#  'NCBIGene:80817',
#  'NCBIGene:83755',
#  'NCBIGene:83899',
#  'NCBIGene:85291',
#  'NCBIGene:85376',
#  'NCBIGene:8601']

# %%
nassociations = len(columns)
print('Number of interactors are {}'.format(nassociations))
# Out:
# Number of interactors are 42

# %%
ggi_df.to_csv('aqp1_expansion/aqp1_ggi.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# ### Get GPh
# #### GET /bioentity/gene/{id}/phenotypes/

# %%
# Download gene-phenotype associations
# id: NCBIGene:358
# Default parameters
# curl -X GET --header 'Accept: application/json' 'https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene%3A358/phenotypes/?rows=20&fetch_objects=true'
# Request url = https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene%3A358/phenotypes/?rows=20&fetch_objects=true

# %%
import urllib3 

# Input gene
gene = 'NCBIGene:358'

# Get phenotypes
# Making requests
# Request parameters
# headers, fields
http = urllib3.PoolManager()
r = http.request('GET', 'https://api.monarchinitiative.org/api/bioentity/gene/%s/phenotypes/'%gene)

# Errors and Exceptions
try:
    http.request('GET', 'https://api.monarchinitiative.org/api/bioentity/gene/%s/phenotypes/'%gene, retries=False)
except urllib3.exceptions.NewConnectionError:
    print('Connection failed.')

# Response content
r.status
r.data
r.headers

# JSON content
json.loads(r.data.decode('utf-8'))
# Out:
# /usr/lib/python3.5/site-packages/urllib3/connectionpool.py:821: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# /usr/lib/python3.5/site-packages/urllib3/connectionpool.py:821: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# {'associations': [],
#  'compact_associations': None,
#  'facet_counts': {'object_closure': {}, 'subject_taxon_label': {}},
#  'facet_pivot': None,
#  'numFound': None,
#  'objects': [],
#  'start': None}

# %%
import requests

# api address
api = 'https://api.monarchinitiative.org/api'
endpoint = '/bioentity'

# input gene
gene = 'NCBIGene:358'

# get gene info
r = requests.get('{}{}/gene/{}'.format(api,endpoint,gene))
#r = requests.get('https://api.monarchinitiative.org/api/bioentity/gene/%s/phenotypes/'%gene, headers={'Accept':'application/json'})
r.headers
r.json()
# Out:
# {'categories': ['gene', 'sequence feature'],
#  'chromosome': {'categories': None,
#   'consider': None,
#   'deprecated': None,
#   'description': None,
#   'id': None,
#   'label': None,
#   'replaced_by': None,
#   'synonyms': None,
#   'taxon': {'id': None, 'label': None},
#   'types': None,
#   'xrefs': None},
#  'consider': None,
#  'deprecated': None,
#  'description': None,
#  'disease_associations': [{'evidence_graph': {'edges': [{'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'},
#      {'obj': 'DOID:899',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015529VL'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015529VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD015529VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'},
#      {'obj': 'PMID:18988797',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'},
#      {'obj': 'DOID:899',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD015529VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Choledochal Cyst'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'DOID:899', 'lbl': 'choledochal cyst'},
#      {'id': 'PMID:18988797', 'lbl': None},
#      {'id': 'MONARCH:8e8f5c993a9ac478fb84f162b39dfdd2b5cf56fe', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '87098b69-b139-40ef-bf2c-485dc301f34a',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:899',
#     'label': 'choledochal cyst',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:18988797',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'DOID:0060164',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'},
#      {'obj': 'PMID:20018876',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD010146VL'},
#      {'obj': 'DOID:0060164',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD010146VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD010146VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d'}],
#     'nodes': [{'id': 'PMID:20018876', 'lbl': None},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD010146VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Pain'},
#      {'id': 'MONARCH:1b5a948ef0ebcc965cefe5f7169e39d5ff08999d', 'lbl': None},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'DOID:0060164', 'lbl': 'pain disorder'}]},
#    'evidence_types': None,
#    'id': '82549ec2-3201-4184-9db0-a5236ffce7d5',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:0060164',
#     'label': 'pain disorder',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:20018876',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'MESH:D015674',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015674VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD015674VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'MESH:D015674',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'PMID:12376462',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD015674VL'}],
#     'nodes': [{'id': 'MONARCH:2b0ef42b50f690cebcf025a345ef07298a4cbb99',
#       'lbl': None},
#      {'id': 'MESH:D015674', 'lbl': 'Mammary Neoplasms, Animal'},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD015674VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Mammary Neoplasms, Animal'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'PMID:12376462', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '72359681-f62a-4d0e-b717-963bb0f2e3ea',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D015674',
#     'label': 'Mammary Neoplasms, Animal',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:12376462',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'DOID:14115',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012772VL'},
#      {'obj': 'DOID:14115',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD012772VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012772VL'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'},
#      {'obj': 'PMID:24028651',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD012772VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Shock, Septic'},
#      {'id': 'PMID:24028651', 'lbl': None},
#      {'id': 'DOID:14115', 'lbl': 'toxic shock syndrome'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:57bc7f1350acedaa6a1acdbea730d62845fd7ecf', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'c47efd46-1ab0-4ea5-85be-b97889991126',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:14115',
#     'label': 'toxic shock syndrome',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:24028651',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'DOID:10763',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD006973VL'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD006973VL'},
#      {'obj': 'DOID:10763',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD006973VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'},
#      {'obj': 'PMID:22228705',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2'}],
#     'nodes': [{'id': 'DOID:10763', 'lbl': 'hypertension'},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD006973VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Hypertension'},
#      {'id': 'MONARCH:00721e590f8ae4f137a25a69a44811851760cdd2', 'lbl': None},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'PMID:22228705', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'af0c53e8-0018-4908-bb8a-364fda43e89f',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:10763',
#     'label': 'hypertension',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:22228705',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD017044VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD017044VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'PMID:18988797',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'OMIM:263200',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e'},
#      {'obj': 'OMIM:263200',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD017044VL'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD017044VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Polycystic Kidney, Autosomal Recessive'},
#      {'id': 'OMIM:263200',
#       'lbl': 'Autosomal recessive polycystic kidney disease'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:746d9325978f120ca018c07fe412b161114df28e', 'lbl': None},
#      {'id': 'PMID:18988797', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'aa764bc1-ca29-4b77-a020-d6a88352802d',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'OMIM:263200',
#     'label': 'Autosomal recessive polycystic kidney disease',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:18988797',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD008325VL'},
#      {'obj': 'MESH:D008325',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD008325VL'},
#      {'obj': 'PMID:12376462',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'},
#      {'obj': 'MESH:D008325',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD008325VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e'}],
#     'nodes': [{'id': ':.well-known/genid/NCBIGene358-MESHD008325VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Mammary Neoplasms, Experimental'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MESH:D008325', 'lbl': 'Mammary Neoplasms, Experimental'},
#      {'id': 'MONARCH:51173b5a100a39be3f3893451b421a050a2f9b3e', 'lbl': None},
#      {'id': 'PMID:12376462', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '24645b90-a77e-480f-b33a-9359928c74ab',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D008325',
#     'label': 'Mammary Neoplasms, Experimental',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:12376462',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD002277VL'},
#      {'obj': 'PMID:12376462',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'},
#      {'obj': 'MESH:D002277',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD002277VL'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD002277VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'},
#      {'obj': 'MESH:D002277',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3'}],
#     'nodes': [{'id': 'MESH:D002277', 'lbl': 'Carcinoma'},
#      {'id': 'MONARCH:60748d2da90761b8c8d2fa9fcc4898c533bc33e3', 'lbl': None},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD002277VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Carcinoma'},
#      {'id': 'PMID:12376462', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '8f99a715-6543-468a-83dc-c060b90021aa',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D002277',
#     'label': 'Carcinoma',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:12376462',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD004489VL'},
#      {'obj': 'PMID:22865611',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': 'MESH:D004489',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD004489VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e'},
#      {'obj': 'MESH:D004489',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD004489VL'}],
#     'nodes': [{'id': 'MESH:D004489', 'lbl': 'Edema, Cardiac'},
#      {'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'PMID:22865611', 'lbl': None},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD004489VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Edema, Cardiac'},
#      {'id': 'MONARCH:e57cd22d86c3c6cd722a088a8377ecce74e09d6e', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '8b6561b0-8092-42b3-8859-7803738560c6',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'MESH:D004489',
#     'label': 'Edema, Cardiac',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:22865611',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'GENO:0000418',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012468VL'},
#      {'obj': 'DOID:8850',
#       'pred': 'RO:0002607',
#       'sub': ':.well-known/genid/NCBIGene358-MESHD012468VL'},
#      {'obj': 'ECO:0000033',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'},
#      {'obj': ':.well-known/genid/NCBIGene358-MESHD012468VL',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'},
#      {'obj': 'PMID:16762588',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'},
#      {'obj': 'DOID:8850',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60'}],
#     'nodes': [{'id': 'ECO:0000033', 'lbl': 'traceable author statement'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:1881a168e7668acc07d4703c88dc33fe9dfa8b60', 'lbl': None},
#      {'id': ':.well-known/genid/NCBIGene358-MESHD012468VL',
#       'lbl': 'some variant of AQP1 that is marker/mechanism for Salivary Gland Neoplasms'},
#      {'id': 'DOID:8850', 'lbl': 'salivary gland cancer'},
#      {'id': 'PMID:16762588', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'c042c18b-535a-41ee-8d08-ad3389d1daf3',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'DOID:8850',
#     'label': 'salivary gland cancer',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': None, 'label': None},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['https://data.monarchinitiative.org/ttl/ctd.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:16762588',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': None,
#     'label': None,
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'families': None,
#  'full_name': None,
#  'function_associations': None,
#  'genotype_associations': [],
#  'homology_associations': [{'evidence_graph': {'edges': [{'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00'},
#      {'obj': 'NCBIGene:843653',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00'},
#      {'obj': 'NCBIGene:843653',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'}],
#     'nodes': [{'id': 'NCBIGene:843653', 'lbl': 'TIP3;1'},
#      {'id': 'MONARCH:d1d6d418685df7bf83082c34537f4ecabb292e00', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '6bac9929-5535-4d13-afe0-db9bce756754',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:843653',
#     'label': 'TIP3;1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:3702', 'label': 'Arabidopsis thaliana'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#      {'obj': 'NCBIGene:123722',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#      {'obj': 'NCBIGene:123722', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'NCBIGene:123722', 'lbl': 'FSD2'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'MONARCH:18fafed02009af95ed344c953ca07f085873576d', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'}]},
#    'evidence_types': None,
#    'id': '565ed0cf-5e0b-4d72-8b20-c6b73740c588',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:123722',
#     'label': 'FSD2',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#      {'obj': 'NCBIGene:22806', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:22806',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'NCBIGene:22806', 'lbl': 'IKZF3'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:a51b2e051b0e4940c3a9bba398cedbf3c928ae34', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '55af1514-49d5-4804-80a0-ddbd5e4b0673',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:22806',
#     'label': 'IKZF3',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'NCBIGene:6925',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc'},
#      {'obj': 'NCBIGene:6925', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:6925', 'lbl': 'TCF4'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:e137091ae20d643cd5323146cf5dda2e5ad8dedc', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '83183ff9-36a7-4f9b-86bc-f0f581403858',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:6925',
#     'label': 'TCF4',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:2353',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#      {'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'},
#      {'obj': 'NCBIGene:2353', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37'}],
#     'nodes': [{'id': 'MONARCH:df0731b14232a1fb6e2d0315d75b9e9a8fc85c37',
#       'lbl': None},
#      {'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'NCBIGene:2353', 'lbl': 'FOS'}]},
#    'evidence_types': None,
#    'id': '5974fd98-a947-495f-a967-3529288824a0',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:2353',
#     'label': 'FOS',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:824647',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6'},
#      {'obj': 'NCBIGene:824647',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'}],
#     'nodes': [{'id': 'MONARCH:73beac4265ac34619b7a5769c4c0b4f577f8caa6',
#       'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:824647', 'lbl': 'PIP2;5'}]},
#    'evidence_types': None,
#    'id': '56b77701-1ba0-4a35-a73d-5d0a2564ae49',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:824647',
#     'label': 'PIP2;5',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:3702', 'label': 'Arabidopsis thaliana'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:816186',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:816186',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62'}],
#     'nodes': [{'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:816186', 'lbl': 'PIP2;8'},
#      {'id': 'MONARCH:3a3e89c6c513efd8d7c5ad14a0b7c02cb9c7ad62', 'lbl': None}]},
#    'evidence_types': None,
#    'id': '7757e857-7eea-4814-8b31-36fa7e1883e0',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:816186',
#     'label': 'PIP2;8',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:3702', 'label': 'Arabidopsis thaliana'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'PMID:25416956',
#       'pred': 'dc:source',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#      {'obj': 'ECO:0000068',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'},
#      {'obj': 'NCBIGene:125115', 'pred': 'RO:0002434', 'sub': 'NCBIGene:358'},
#      {'obj': 'NCBIGene:125115',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858'}],
#     'nodes': [{'id': 'ECO:0000068', 'lbl': 'yeast 2-hybrid evidence'},
#      {'id': 'NCBIGene:125115', 'lbl': 'KRT40'},
#      {'id': 'PMID:25416956', 'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:e6a8b07a0d4f5c820c093be7dbfe6003722a0858', 'lbl': None}]},
#    'evidence_types': None,
#    'id': 'd93622d5-b3ce-4014-9566-165d8edbdd0b',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:125115',
#     'label': 'KRT40',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/biogrid.ttl'],
#    'publications': [{'categories': None,
#      'consider': None,
#      'deprecated': None,
#      'description': None,
#      'id': 'PMID:25416956',
#      'label': None,
#      'replaced_by': None,
#      'synonyms': None,
#      'types': None}],
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:0002434',
#     'label': 'interacts with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'FlyBase:FBgn0015872',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a'},
#      {'obj': 'FlyBase:FBgn0015872',
#       'pred': 'RO:HOM0000017',
#       'sub': 'NCBIGene:358'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a'}],
#     'nodes': [{'id': 'FlyBase:FBgn0015872', 'lbl': 'Drip'},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'MONARCH:e8bdb6736d7be62554d582fe810bf24186160a9a', 'lbl': None},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'}]},
#    'evidence_types': None,
#    'id': '5b335768-c3d1-418a-a7fb-c1c48339e9f6',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'FlyBase:FBgn0015872',
#     'label': 'Drip',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:7227', 'label': 'Drosophila melanogaster'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000017',
#     'label': 'in orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None},
#   {'evidence_graph': {'edges': [{'obj': 'NCBIGene:420384',
#       'pred': 'OBAN:association_has_object',
#       'sub': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd'},
#      {'obj': 'NCBIGene:420384',
#       'pred': 'RO:HOM0000020',
#       'sub': 'NCBIGene:358'},
#      {'obj': 'ECO:0000080',
#       'pred': 'RO:0002558',
#       'sub': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd'},
#      {'obj': 'NCBIGene:358',
#       'pred': 'OBAN:association_has_subject',
#       'sub': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd'}],
#     'nodes': [{'id': 'MONARCH:7e310ad3c245130eff113ada3f1aebbb965740bd',
#       'lbl': None},
#      {'id': 'NCBIGene:358', 'lbl': 'AQP1'},
#      {'id': 'ECO:0000080', 'lbl': 'phylogenetic evidence'},
#      {'id': 'NCBIGene:420384', 'lbl': 'AQP1'}]},
#    'evidence_types': None,
#    'id': 'b880991b-2292-4ac8-8bea-79ae9b9f56dc',
#    'object': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:420384',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9031', 'label': 'Gallus gallus'},
#     'types': None,
#     'xrefs': None},
#    'object_extension': None,
#    'provided_by': ['http://data.monarchinitiative.org/ttl/panther.ttl'],
#    'publications': None,
#    'qualifiers': None,
#    'relation': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'RO:HOM0000020',
#     'label': 'in 1 to 1 orthology relationship with',
#     'replaced_by': None,
#     'synonyms': None,
#     'types': None},
#    'slim': None,
#    'subject': {'categories': None,
#     'consider': None,
#     'deprecated': None,
#     'description': None,
#     'id': 'NCBIGene:358',
#     'label': 'AQP1',
#     'replaced_by': None,
#     'synonyms': None,
#     'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#     'types': None,
#     'xrefs': None},
#    'subject_extension': None,
#    'type': None}],
#  'id': 'NCBIGene:358',
#  'interaction_associations': None,
#  'label': 'AQP1',
#  'literature_associations': None,
#  'pathway_associations': None,
#  'phenotype_associations': [],
#  'replaced_by': None,
#  'sequence_features': None,
#  'summaries': None,
#  'synonyms': [{'pred': 'synonym',
#    'val': 'channel-like integral membrane protein, 28-kDa',
#    'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'water channel protein for red blood cells and kidney proximal tubule',
#    'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'aquaporin 1 (Colton blood group)',
#    'xrefs': None},
#   {'pred': 'synonym', 'val': 'aquaporin-1', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'AQP1_HUMAN', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'urine water channel', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'CO', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'AQP1', 'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'aquaporin 1 (channel-forming integral protein, 28kDa, CO blood group)',
#    'xrefs': None},
#   {'pred': 'synonym',
#    'val': 'aquaporin 1, Colton blood group antigen',
#    'xrefs': None},
#   {'pred': 'synonym', 'val': 'aquaporin-CHIP', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'AQP-CHIP', 'xrefs': None},
#   {'pred': 'synonym', 'val': 'CHIP28', 'xrefs': None}],
#  'systematic_name': None,
#  'taxon': {'id': 'NCBITaxon:9606', 'label': 'Homo sapiens'},
#  'transcripts': None,
#  'types': None,
#  'xrefs': None}

# %%
# get gene-phenotype
r = requests.get('{}{}/gene/{}/phenotypes/'.format(api,endpoint,gene))
nassociations = len(r.json()['associations'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 0

# %%
# get gene-disease
r = requests.get('{}{}/gene/{}/diseases/'.format(api,endpoint,gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of diseases associated are 13

# %%
r_dict = r.json()
gda_df = json_normalize(r_dict, 'objects')
gda_df.columns = ['disease_id']
gda_df.head(2)
# Out:
#      disease_id
# 0  DOID:0060164
# 1    DOID:10763

# %%
gda_df.to_csv('aqp1_expansion/aqp1_gene_disease.tsv', sep='\t', index=False, header=True)

# %%
# get gene-function
r = requests.get('{}{}/gene/{}/function/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
r.json()
# Out:
# Number of diseases associated are 0
# {'associations': [],
#  'compact_associations': None,
#  'facet_counts': {'isa_partof_closure': {}, 'taxon_label': {}},
#  'facet_pivot': None,
#  'numFound': None,
#  'objects': [],
#  'start': None}

# %%
# get gene-expressedInAnatomy
r = requests.get('{}{}/gene/{}/expressed/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 20

# %%
r_data = r.json()
gaa_df = json_normalize(r_data, 'objects')
gaa_df.columns = ['expressed_in_anatomy']
gaa_df.head(2)
# Out:
#   expressed_in_anatomy
# 0       UBERON:0000007
# 1       UBERON:0000057

# %%
gaa_df.to_csv('aqp1_expansion/aqp1_gene_anatomy.tsv', sep='\t', index=False, header=True)

# %%
# get gene-pub
r = requests.get('{}{}/gene/{}/pubs/'.format(api, endpoint, gene))
nassociations = len(r.json()['objects'])
print('Number of nodes associated are {}'.format(nassociations))
# Out:
# Number of nodes associated are 0
